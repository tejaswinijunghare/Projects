# %%
import pandas as pd

# load dataset
df = pd.read_csv('D:/iPrimed/Persistence/Data/gradedata.csv')

# find datatype of each column
data_types = pd.DataFrame(df.dtypes, columns=['Data Type'])

# count number of missing observations by column
missing_data_counts = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])

# count number of present observations by column
present_data_counts = pd.DataFrame(df.count(), columns=['Present Values'])

# count number of unique observations by column
unique_value_counts = pd.DataFrame(columns=['Unique Values'])
for v in list(df.columns.values):
	unique_value_counts.loc[v] = [df[v].nunique()]
	
# find minimum value for each column
minimum_values = pd.DataFrame(columns=['Minimum Values'])
for v in list(df.columns.values):
	minimum_values.loc[v] = [df[v].min()]

# find maximum value for each column
maximum_values = pd.DataFrame(columns=['Maximum Values'])
for v in list(df.columns.values):
	maximum_values.loc[v] = [df[v].max()]

data_quality_report = pd.concat([present_data_counts, missing_data_counts, unique_value_counts,
									minimum_values, maximum_values], axis=1)
print(data_quality_report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

data = {'Name':['Bob','Jessica','Mary','John','Mel'],
		'Grade':[76,83,77,78,95]}
		
df = pd.DataFrame(data)
print(df)

df.plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Name':['Bob','Jessica','Mary','John','Mel'],
		'Grade':[76,83,77,78,95]}
		
df = pd.DataFrame(data)
print(df)

df.plot()

displayText = "Line Plot"
xloc = 1
yloc = df['Grade'].max()
xtext = 8
ytext = -150
plt.annotate(displayText, xy=(xloc, yloc), arrowprops=dict(facecolor='black', shrink=0.05),
				xytext=(xtext,ytext), xycoords=('axes fraction', 'data'), textcoords='offset points')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Name':['Bob','Jessica','Mary','John','Mel'],		
		'Grade':[76,83,77,78,95]}
		
df = pd.DataFrame(data)
print(df)

#df.plot(kind='bar')
#plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Name':['Bob','Jessica','Mary','John','Mel'],		
		'Grade':[76,83,77,78,95]}
		
df = pd.DataFrame(data)
df = df.set_index(df['Name'])
print(df)

df.plot(kind='bar')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Name':['Bob','Jessica','Mary','John','Mel'],		
		'Grade':[76,95,77,78,99],
		'Gender':['Male','Female','Female','Male','Female'],
		'Status':['Senior','Senior','Junior','Junior','Senior']}
		
df = pd.DataFrame(data)
print(df)
print(df.describe())

df.boxplot(column='Grade')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# dataset contains outlier - Charles with a grade of 130

data = {'Name':['Bob','Jessica','Mary','John','Mel','Charles'],		
		'Grade':[76,95,77,78,99,130],
		'Gender':['Male','Female','Female','Male','Female','Male'],
		'Status':['Senior','Senior','Junior','Junior','Senior','Senior']}
		
df = pd.DataFrame(data)
print(df)
print(df.describe())

df.boxplot(column='Grade')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Name':['Bob','Jessica','Mary','John','Mel'],		
		'Grade':[76,95,77,78,99],
		'Gender':['Male','Female','Female','Male','Female'],
		'Status':['Senior','Senior','Junior','Junior','Senior']}
		
df = pd.DataFrame(data)
print(df)
print(df.describe())

axis1 = df.boxplot(by='Gender', column='Grade')
axis1.set_ylim(0,100)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load dataset
df = pd.read_csv('D:/iPrimed/Persistence/Data/gradedata.csv')
df.hist()
df.hist(column='hours')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load dataset
df = pd.read_csv('D:/iPrimed/Persistence/Data/gradedata.csv')
df.hist(column='hours', by='gender')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Name':['Bob','Jessica','Mary','John','Mel'],		
		'Absence':[3,0,1,0,8],
		'Detention':[2,1,0,0,1],
		'Warning':[2,1,5,1,2]}
		
df = pd.DataFrame(data)
df['TotalDemerits'] = df['Absence'] + df['Detention'] + df['Warning']

plt.pie(df['TotalDemerits'], labels=df['Name'], explode=(0,0,0,0,0.15), 
			startangle=90, autopct='%1.1f%%',)
plt.axis('equal')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'Col': np.random.normal(size=200)})
plt.scatter(df.index, df['Col'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load dataset
df = pd.read_csv('D:/iPrimed/Persistence/Data/gradedata.csv')

print(df.describe())
print(df.skew())
print(df.kurtosis())

df.hist()
df['age'].plot.density()
df['exercise'].plot.density()
df['hours'].plot.density()
df['grade'].plot.density()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load dataset
df = pd.read_csv('D:/iPrimed/Persistence/Data/gradedata.csv')

print(df.corr(method='pearson'))

df.plot.scatter('grade', 'hours')
plt.show()

# %%
import pandas as pd

data = {'A':['A1','A2','A3'],'B':['B1','B2','B3'],'C':['C1','C2','C3'],}

df = pd.DataFrame(data, index=[1,2,3])
#print(df[B])
#print(df.B)
#print(df.loc['B'])
#print(df.ix['B'])
df = df.add('D',axis=1)
print(df)

# %% [markdown]
# Boston Housing Dataset
#
# This exercise is based on the Boston Housing dataset taken from the UCI Machine Learning
# Repository (originally from the CMU StatLib Library) –
# http://archive.ics.uci.edu/ml/datasets/Housing
# .
#
# The original source of the dataset is attributed to:
# Harrison, D., Rubinfeld, D.L., “Hedonic Prices and the Demand for Clean Air”,
# Journal of Environmental Economics & Management (5), 1978, pp. 81–102.
#
# The multivariate dataset is concerned with housing values in the suburbs of Boston. The
# dataset consists of 506 records with 13 continuous variables and 1 binary variable. The
# dependent variable is MEDV. There is no missing data. A description of each variable is
# provided below:
#
# 1. CRIM – per capita crime rate by town
# 2. ZN – proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS – proportion of non–retail business acres per town
# 4. CHAS – Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# 5. NOX – nitric oxides concentration (parts per 10 million)
# 6. RM – average number of rooms per dwelling
# 7. AGE – proportion of owner–occupied units built prior to 1940
# 8. DIS – weighted distances to five Boston employment centres
# 9. RAD – index of accessibility to radial highways
# 10. TAX – full-value property-tax rate per $10,000
# 11. PTRATIO – pupil-teacher ratio by town
# 12. B – 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT – % lower status of the population
# 14. MEDV – Median value of owner-occupied homes in $1000's
#
# A multiple linear regression would typically be used in this case to analyse how the
# independent variables (i.e., predictive variables) affect the dependent variable (i.e.,
# target/label/class variable), i.e., MEDV.
#
# Perform an exploratory data analysis and discuss your findings about the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('D:/iPrimed/Persistence/Data/BostonHousing.csv')

print(df)

print(df.describe())
#df.hist()

#df.plot.scatter('AGE','TAX')
#df.plot.scatter('INDUS','CHAS')
df.plot.scatter('AGE','CRIM')
df.plot.scatter('CRIM','AGE')
plt.show()
